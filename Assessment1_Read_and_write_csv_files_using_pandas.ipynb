# %%
import pandas as pd

# %%
# manually creating a data frame
df=pd.DataFrame(
    {
        
        "name":["Parul, Mehta",
               "XXX,yyyy"],
        "age": [22,11]
    }
)

# %%
df=pd.read_csv("dummydata.csv", sep=';')

# %%
df
# Out:
#             country     area  birth_rate  current_account_balance  death_rate  \
# 0       Afghanistan   647500       47.02                      NaN       20.75
# 1          Akrotiri      123         NaN                      NaN         NaN
# 2           Albania    28748       15.08            -5.040000e+08        5.12
# 3           Algeria  2381740       17.13             1.190000e+10        4.60
# 4    American Samoa      199       23.13                      NaN        3.33
# ..              ...      ...         ...                      ...         ...
# 258       West Bank     5860       32.37                      NaN        3.99
# 259  Western Sahara   266000         NaN                      NaN         NaN
# 260           Yemen   527970       43.07             3.699000e+08        8.53
# 261          Zambia   752614       41.38            -1.814000e+08       20.23
# 262        Zimbabwe   390580       29.74            -2.303000e+08       24.66
#
# ...

# %%
df.head()
# Out:
#           country     area  birth_rate  current_account_balance  death_rate  \
# 0     Afghanistan   647500       47.02                      NaN       20.75
# 1        Akrotiri      123         NaN                      NaN         NaN
# 2         Albania    28748       15.08            -5.040000e+08        5.12
# 3         Algeria  2381740       17.13             1.190000e+10        4.60
# 4  American Samoa      199       23.13                      NaN        3.33
#
#            debt  e_consumption  e_production       Exports           GDP  ...  \
# 0  8.000000e+09   6.522000e+08  5.400000e+08  4.460000e+08  2.150000e+10  ...
# 1           NaN            NaN           NaN           NaN           NaN  ...
# 2  1.410000e+09   6.760000e+09  5.680000e+09  5.524000e+08  1.746000e+10  ...
# 3  2.190000e+10   2.361000e+10  2.576000e+10  3.216000e+10  2.123000e+11  ...
# 4           NaN   1.209000e+08  1.300000e+08  3.000000e+07  5.000000e+08  ...
#
# ...

# %%
df.tail()
# Out:
#             country    area  birth_rate  current_account_balance  death_rate  \
# 258       West Bank    5860       32.37                      NaN        3.99
# 259  Western Sahara  266000         NaN                      NaN         NaN
# 260           Yemen  527970       43.07              369900000.0        8.53
# 261          Zambia  752614       41.38             -181400000.0       20.23
# 262        Zimbabwe  390580       29.74             -230300000.0       24.66
#
#              debt  e_consumption  e_production       Exports           GDP  \
# 258  1.080000e+08            NaN           NaN  2.050000e+08  1.800000e+09
# 259           NaN   8.370000e+07  9.000000e+07           NaN           NaN
# 260  5.400000e+09   2.827000e+09  3.040000e+09  4.468000e+09  1.625000e+10
# 261  5.353000e+09   5.345000e+09  8.167000e+09  1.548000e+09  9.409000e+09
# 262  4.086000e+09   1.122000e+10  8.839000e+09  1.409000e+09  2.437000e+10
#
# ...

# %%
# Reading a series
df["country"]
# Out:
# 0         Afghanistan
# 1            Akrotiri
# 2             Albania
# 3             Algeria
# 4      American Samoa
#             ...
# 258         West Bank
# 259    Western Sahara
# 260             Yemen
# 261            Zambia
# 262          Zimbabwe
# Name: country, Length: 263, dtype: object

# %%
max=df["country"].max()

# %%
df["area"].describe()
# Out:
# count    2.630000e+02
# mean     5.849875e+05
# std      1.881416e+06
# min      0.000000e+00
# 25%      5.130000e+02
# 50%      4.884500e+04
# 75%      3.339475e+05
# max      1.707520e+07
# Name: area, dtype: float64

# %%
df.dtypes
# Out:
# country                                            object
# area                                                int64
# birth_rate                                        float64
# current_account_balance                           float64
# death_rate                                        float64
# debt                                              float64
# e_consumption                                     float64
# e_production                                      float64
# Exports                                           float64
# GDP                                               float64
# GDP - per capita                                  float64
# GDP - real growth rate(%)                         float64
# HIV/AIDS - adult prevalence rate(%)               float64
# HIV/AIDS - deaths                                 float64
# HIV/AIDS - people living with HIV/AIDS            float64
# Highways(km)                                      float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 45 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   country                                         263 non-null    object
#  1   area                                            263 non-null    int64
#  2   birth_rate                                      225 non-null    float64
#  3   current_account_balance                         149 non-null    float64
#  4   death_rate                                      225 non-null    float64
#  5   debt                                            201 non-null    float64
#  6   e_consumption                                   215 non-null    float64
#  7   e_production                                    213 non-null    float64
#  8   Exports                                         224 non-null    float64
# ...

# %%
df.to_excel("dummydata.xlsx", sheet_name="dummy", index=False)

# %%
country=df["country"]

# %%
country.head()
# Out:
# 0       Afghanistan
# 1          Akrotiri
# 2           Albania
# 3           Algeria
# 4    American Samoa
# Name: country, dtype: object

# %%
country.shape
# Out:
# (263,)

# %%
df.shape
# Out:
# (263, 45)

# %%
country_area=df[["country","area"]]

# %%
country_area
# Out:
#             country     area
# 0       Afghanistan   647500
# 1          Akrotiri      123
# 2           Albania    28748
# 3           Algeria  2381740
# 4    American Samoa      199
# ..              ...      ...
# 258       West Bank     5860
# 259  Western Sahara   266000
# 260           Yemen   527970
# 261          Zambia   752614
# 262        Zimbabwe   390580
#
# [263 rows x 2 columns]

# %%
type(country_area)
# Out:
# pandas.core.frame.DataFrame

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
new_df=df[df["country"]==max]

# %%
new_df
# Out:
#       country    area  birth_rate  current_account_balance  death_rate  \
# 262  Zimbabwe  390580       29.74             -230300000.0       24.66
#
#              debt  e_consumption  e_production       Exports           GDP  \
# 262  4.086000e+09   1.122000e+10  8.839000e+09  1.409000e+09  2.437000e+10
#
#      ...  Oil - production(bbl/day)  Oil - proved reserves(bbl)  Population  \
# 262  ...                        0.0                         NaN  12746990.0
#
#      Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 262                   52.3        3077.0                           57000000.0
#
#      Telephones - main lines in use  Telephones - mobile cellular  \
# 262                        300900.0                      379100.0
#
#      Total fertility rate(children born/woman)  Unemployment rate(%)
# 262                                       3.54                  70.0
#
# [1 rows x 45 columns]

# %%
new_df=df[(df["country"]==max) | (df["country"]=="Australia")]

# %%
new_df
# Out:
#        country     area  birth_rate  current_account_balance  death_rate  \
# 14   Australia  7686850       12.26            -3.830000e+10        7.44
# 262   Zimbabwe   390580       29.74            -2.303000e+08       24.66
#
#              debt  e_consumption  e_production       Exports           GDP  \
# 14   3.087000e+11   1.956000e+11  2.103000e+11  8.689000e+10  6.117000e+11
# 262  4.086000e+09   1.122000e+10  8.839000e+09  1.409000e+09  2.437000e+10
#
#      ...  Oil - production(bbl/day)  Oil - proved reserves(bbl)  Population  \
# 14   ...                   537500.0                3.664000e+09  20090437.0
# 262  ...                        0.0                         NaN  12746990.0
#
#      Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 14                    17.4       43802.0                         3.514000e+10
# 262                   52.3        3077.0                         5.700000e+07
#
# ...

# %%
new_df=df.loc[(df["country"]==max) | (df["country"]=="Australia"),["country","area"]]

# %%
new_df
# Out:
#        country     area
# 14   Australia  7686850
# 262   Zimbabwe   390580

# %%
new_df=df[df["birth_rate"].notna()]

# %%
new_df.shape
# Out:
# (225, 45)

# %%
new_df=df[df["birth_rate"].isin([0.25,0.35])]

# %%
new_df.shape
# Out:
# (0, 45)

# %%
new_df=df.iloc[2:25,0:34]

# %%
new_df
# Out:
#                         country      area  birth_rate  \
# 2                       Albania     28748       15.08
# 3                       Algeria   2381740       17.13
# 4                American Samoa       199       23.13
# 5                       Andorra       468        9.00
# 6                        Angola   1246700       44.64
# 7                      Anguilla       102       14.26
# 8                    Antarctica  14000000         NaN
# 9           Antigua and Barbuda       443       17.26
# 10                    Argentina   2766890       16.90
# 11                      Armenia     29800       11.76
# 12                        Aruba       193       11.26
# 13  Ashmore and Cartier Islands         5         NaN
# 14                    Australia   7686850       12.26
# 15                      Austria     83870        8.81
# 16                   Azerbaijan     86600       20.40
# 17                  Bahamas The     13940       17.87
# ...

# %%
new_df.columns
# Out:
# Index(['country', 'area', 'birth_rate', 'current_account_balance',
#        'death_rate', 'debt', 'e_consumption', 'e_production', 'Exports', 'GDP',
#        'GDP - per capita', 'GDP - real growth rate(%)',
#        'HIV/AIDS - adult prevalence rate(%)', 'HIV/AIDS - deaths',
#        'HIV/AIDS - people living with HIV/AIDS', 'Highways(km)', 'Imports',
#        'Industrial production growth rate(%)',
#        'Infant mortality rate(deaths/1000 live births)',
#        'Inflation rate (consumer prices)(%)', 'Internet hosts',
#        'Internet users', 'Investment (gross fixed)(% of GDP)', 'Labor force',
#        'Life expectancy at birth(years)',
#        'Military expenditures - dollar figure',
#        'Military expenditures - percent of GDP(%)',
#        'Natural gas - consumption(cu m)', 'Natural gas - exports(cu m)',
#        'Natural gas - imports(cu m)', 'Natural gas - production(cu m)',
#        'Natural gas - proved reserves(cu m)', 'Oil - consumption(bbl/day)',
# ...

# %%
new_df.values
# Out:
# array([['Albania', 28748, 15.08, -504000000.0, 5.12, 1410000000.0,
#         6760000000.0, 5680000000.0, 552400000.0, 17460000000.0, 4900.0,
#         5.6, nan, nan, nan, 18000.0, 2076000000.0, 3.1, 21.52, 3.2,
#         455.0, 30000.0, 18.4, 1090000.0, 77.24, 56500000.0, 1.49,
#         30000000.0, 0.0, 0.0, 30000000.0, 3316000000.0, 7500.0, 0.0],
#        ['Algeria', 2381740, 17.13, 11900000000.0, 4.6, 21900000000.0,
#         23610000000.0, 25760000000.0, 32160000000.0, 212300000000.0,
#         6600.0, 6.1, 0.1, 500.0, 9100.0, 104000.0, 15250000000.0, 6.0,
#         31.0, 3.1, 897.0, 500000.0, 26.2, 9910000.0, 73.0, 2480000000.0,
#         3.2, 22320000000.0, 57980000000.0, 0.0, 80300000000.0,
#         4739000000000.0, 209000.0, nan],
#        ['American Samoa', 199, 23.13, nan, 3.33, nan, 120900000.0,
#         130000000.0, 30000000.0, 500000000.0, 8000.0, nan, nan, nan, nan,
#         185.0, 123000000.0, nan, 9.27, nan, nan, nan, nan, 14000.0,
# ...
