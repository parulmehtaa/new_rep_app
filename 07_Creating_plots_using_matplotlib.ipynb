# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
df.iloc[:,1:3].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
# plotting scatter chart
df
# df.plot.scatter(x=df.iloc[:,1:2],y=df.iloc[:,2:3])
df.plot.scatter(x="station_london", y="station_paris")
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
ts=pd.Series(np.random.randint(-1000,1000, size=(1000)), index=(pd.date_range("1/1/2018",periods=1000)))

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts=ts.cumsum()

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randint(-1000,1000, size=(1000,3)), index=(pd.date_range("1/1/2018",periods=1000)), columns=['col1','col2','col3'])

# %%
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>
